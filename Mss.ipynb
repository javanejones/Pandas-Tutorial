# %% [markdown]
# # Hello MSS

# %% [markdown]
# ## Welcome to quick tutorial of python pandas

# %% [markdown]
# - Pandas is one of the most commonly used Python packages/libraries for data science.<br><br>
# - Pandas is Python's answer for making two dimensional tables (ala Excel and SQL).<br><br>
# - Pandas calls a table a "DataFrame".<br><br>
# - Pandas DataFrames are used by Python's other packages for statistical analysis, data manipulation, and data visualization.<br><br>
# - Pandas DataFrames can be exported as .csv and other files.<br><br>

# %% [markdown]
# ### If you are using Google Colab, you must run the next line of code.

# %%
# Getting the excel file into google colab
# !wget https://raw.githubusercontent.com/javanejones/Pandas-Tutorial/main/mss.xlsx

# %%
# !pip install pandas

# %%
import pandas as pd

# %% [markdown]
# ## Core components of pandas: Series and DataFrames
#
# - The primary two components of pandas are the Series and DataFrame.
#
# - A Series is essentially a column, and a DataFrame is a multi-dimensional table made up of a collection of Series.

# %%
# Example of Series
# This is also known as a dictionary
data = {
    'Peaches':[3,2,0,1],
    'oranges':[0, 3, 7, 2]
}
data
# Out:
# {'Peaches': [3, 2, 0, 1], 'oranges': [0, 3, 7, 2]}

# %%
# Example of Dataframe
dataframe = pd.DataFrame(data)
dataframe
# Out:
#    Peaches  oranges
# 0        3        0
# 1        2        3
# 2        0        7
# 3        1        2

# %%
# Replacing the index of a dataframe
replace = pd.DataFrame(data, index=['Jack','Bob', 'Dave', 'Cliff'])
replace
# Out:
#        Peaches  oranges
# Jack         3        0
# Bob          2        3
# Dave         0        7
# Cliff        1        2

# %% [markdown]
# ### Loading files into python
#
# Below are a few examples of reading files into python
#
# - pd.read_csv()
# - pd.read_excel()
# - pd.read_html()
# - and many more

# %% [markdown]
# ## Loading excel into python

# %% [markdown]
# ### Excel Work Sheets
#
# Concat= combine all worksheets into one dataframe exmple below:
#
# - df = pd.concat(pd.read_excel('filename.xlsx', sheet_name=None, ignore_index=True))
#
# Individual work sheets use for best results!! exmple below:
#
# - df = pd.read_excel('filename.xlsx', sheet_name='sheetname')
#
# #### or
#
# - df = pd.read_excel('filename.xlsx', sheet_name=0)
#
# - 0 represents sheet 1.
#
# View all worksheets in the file exmple below:
#
# - df = pd.read_excel('filename.xlsx', sheet_name=None)

# %%
# Concat
df = pd.concat(pd.read_excel('mss.xlsx', sheet_name=None))
df
# Out:
#             OrderDate   Region       Rep    Item  Units  UnitCost    Total
# 2017-18 0  2018-09-01  Central     Smith    Desk      2    125.00   250.00
#         1  2018-06-17  Central    Kivell    Desk      5    125.00   625.00
#         2  2018-09-10  Central      Gill  Pencil      7      1.29     9.03
#         3  2018-11-17  Central   Jardine  Binder     11      4.99    54.89
#         4  2018-10-31  Central   Andrews  Pencil     14      1.29    18.06
# ...               ...      ...       ...     ...    ...       ...      ...
# 2019-20 38 2019-05-22     West  Thompson  Pencil     32      1.99    63.68
#         39 2020-03-07     West   Sorvino  Binder      7     19.99   139.93
#         40 2020-08-24     West   Sorvino    Desk      3    275.00   825.00
#         41 2020-09-27     West   Sorvino     Pen     76      1.99   151.24
#         42 2020-10-14     West  Thompson  Binder     57     19.99  1139.43
#
# [86 rows x 7 columns]

# %%
# Individually

#Displays each excel sheet separately into a dataframe

# This is the best option

df1 = pd.read_excel('mss.xlsx', sheet_name=0)

# df2 = pd.read_excel('mss.xlsx', sheet_name=1)

# or

# df1 = pd.read_excel('mss.xlsx', sheet_name='2017-18')

df2 = pd.read_excel('mss.xlsx', sheet_name='2019-20')

# %%
#Displays All Worksheets
# This becomes a dictionary
df3= pd.read_excel('mss.xlsx', sheet_name=None)
# df3

# %%
#Displays the Top 5 rows of Data
df1.head()
# Out:
#    OrderDate   Region      Rep    Item  Units  UnitCost   Total
# 0 2018-09-01  Central    Smith    Desk      2    125.00  250.00
# 1 2018-06-17  Central   Kivell    Desk      5    125.00  625.00
# 2 2018-09-10  Central     Gill  Pencil      7      1.29    9.03
# 3 2018-11-17  Central  Jardine  Binder     11      4.99   54.89
# 4 2018-10-31  Central  Andrews  Pencil     14      1.29   18.06

# %%
#Displays the Bottom 5 rows of Data
df1.tail()
# Out:
#     OrderDate Region       Rep    Item  Units  UnitCost    Total
# 38 2018-03-07   West   Sorvino  Binder      7     19.99   139.93
# 39 2017-05-22   West  Thompson  Pencil     32      1.99    63.68
# 40 2017-03-18   West   Sorvino  Pencil     56      2.99   167.44
# 41 2018-10-17   West  Thompson  Binder     57     19.99  1139.43
# 42 2018-09-27   West   Sorvino     Pen     76      1.99   151.24

# %%
# View Columns in data

df1.keys()

# or
# Out:
# Index(['OrderDate', 'Region', 'Rep', 'Item', 'Units', 'UnitCost', 'Total'], dtype='object')

# %%
# View Columns in data

df2.columns
# Out:
# Index(['OrderDate', 'Region', 'Rep', 'Item', 'Units', 'UnitCost', 'Total'], dtype='object')

# %%
#Identifying the type of data
df1.dtypes
# Out:
# OrderDate    datetime64[ns]
# Region               object
# Rep                  object
# Item                 object
# Units                 int64
# UnitCost            float64
# Total               float64
# dtype: object

# %%
# Changing the view

#Displays reverse the display of columns and rows 

df1.T
# Out:
#                             0                    1                    2   \
# OrderDate  2018-09-01 00:00:00  2018-06-17 00:00:00  2018-09-10 00:00:00
# Region                 Central              Central              Central
# Rep                      Smith               Kivell                 Gill
# Item                      Desk                 Desk               Pencil
# Units                        2                    5                    7
# UnitCost                   125                  125                 1.29
# Total                      250                  625                 9.03
#
#                             3                    4                    5   \
# OrderDate  2018-11-17 00:00:00  2018-10-31 00:00:00  2017-02-26 00:00:00
# Region                 Central              Central              Central
# Rep                    Jardine              Andrews                 Gill
# Item                    Binder               Pencil                  Pen
# Units                       11                   14                   27
# UnitCost                  4.99                 1.29                19.99
# Total                    54.89                18.06               539.73
#
#                             6                    7                    8   \
# OrderDate  2017-10-05 00:00:00  2018-12-21 00:00:00  2017-02-09 00:00:00
# Region                 Central              Central              Central
# Rep                     Morgan              Andrews              Jardine
# Item                    Binder               Binder               Pencil
# Units                       28                   28                   36
# UnitCost                  8.99                 4.99                 4.99
# Total                   251.72               139.72               179.64
#
#                             9   ...                   33                   34  \
# OrderDate  2018-08-07 00:00:00  ...  2017-12-29 00:00:00  2017-07-29 00:00:00
# Region                 Central  ...                 East                 East
# Rep                     Kivell  ...               Parent               Parent
# Item                   Pen Set  ...              Pen Set               Binder
# Units                       42  ...                   74                   81
# UnitCost                 23.95  ...                15.99                19.99
# Total                   1005.9  ...              1183.26              1619.19
#
#                             35                   36                   37  \
# OrderDate  2017-01-06 00:00:00  2018-04-27 00:00:00  2018-08-24 00:00:00
# Region                    East                 East                 West
# Rep                      Jones               Howard              Sorvino
# Item                    Pencil                  Pen                 Desk
# Units                       95                   96                    3
# UnitCost                  1.99                 4.99                  275
# Total                   189.05               479.04                  825
#
#                             38                   39                   40  \
# OrderDate  2018-03-07 00:00:00  2017-05-22 00:00:00  2017-03-18 00:00:00
# Region                    West                 West                 West
# Rep                    Sorvino             Thompson              Sorvino
# Item                    Binder               Pencil               Pencil
# Units                        7                   32                   56
# UnitCost                 19.99                 1.99                 2.99
# Total                   139.93                63.68               167.44
#
#                             41                   42
# OrderDate  2018-10-17 00:00:00  2018-09-27 00:00:00
# Region                    West                 West
# Rep                   Thompson              Sorvino
# Item                    Binder                  Pen
# Units                       57                   76
# UnitCost                 19.99                 1.99
# Total                  1139.43               151.24
#
# [7 rows x 43 columns]

# %%
# .info() should be one of the very first commands you run after loading your data:
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 43 entries, 0 to 42
# Data columns (total 7 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   OrderDate  43 non-null     datetime64[ns]
#  1   Region     43 non-null     object
#  2   Rep        43 non-null     object
#  3   Item       43 non-null     object
#  4   Units      43 non-null     int64
#  5   UnitCost   43 non-null     float64
#  6   Total      43 non-null     float64
# dtypes: datetime64[ns](1), float64(2), int64(1), object(3)
# memory usage: 2.5+ KB

# %% [markdown]
# ## Data Types
#
# ### object: str or mixed,	Usage =	Text or mixed numeric and non-numeric values
#
# #### Examples:
# - x = John
# - y = 52x
# - z = John##
#
# ### int64: int, Usage= Integer numbers
#
# #### Examples:
# - x = 1
# - y = 35656222554887711
# - z = -3255522
#
# ### float64: float, Usage= Floating point numbers
#
# #### Examples:
# - x = 1.10 or x = 35e3
# - y = 1.0 or y = 12E4
# - z = -35.59 or z = -87.7e100
#
# ### bool: bool Usage= True/False values
#
# #### Examples:
#
# - print(10 > 9) True      > greater than
# - print(10 == 9) False    == equal
# - print(10 < 9) False     < - less than
#
# ### datetime64: Usage= Date and time values
#
# #### Examples:
# - x = 2020-01-01
# - y = 01-5-2020

# %%
#Breaks down the rows and columns in table (rows, columns):
df1.shape
# Out:
# (43, 7)

# %%
# View all data in dataframe

df1.head(10)
# Out:
#    OrderDate   Region      Rep     Item  Units  UnitCost    Total
# 0 2018-09-01  Central    Smith     Desk      2    125.00   250.00
# 1 2018-06-17  Central   Kivell     Desk      5    125.00   625.00
# 2 2018-09-10  Central     Gill   Pencil      7      1.29     9.03
# 3 2018-11-17  Central  Jardine   Binder     11      4.99    54.89
# 4 2018-10-31  Central  Andrews   Pencil     14      1.29    18.06
# 5 2017-02-26  Central     Gill      Pen     27     19.99   539.73
# 6 2017-10-05  Central   Morgan   Binder     28      8.99   251.72
# 7 2018-12-21  Central  Andrews   Binder     28      4.99   139.72
# 8 2017-02-09  Central  Jardine   Pencil     36      4.99   179.64
# 9 2018-08-07  Central   Kivell  Pen Set     42     23.95  1005.90

# %%
# Combine the data into one using concat

# data =[df1,df2]
# combine = pd.concat(data,ignore_index=True)

# or

combine = pd.concat([df1,df2], join='inner',ignore_index=True)
combine.head()
# Out:
#    OrderDate   Region      Rep    Item  Units  UnitCost   Total
# 0 2018-09-01  Central    Smith    Desk      2    125.00  250.00
# 1 2018-06-17  Central   Kivell    Desk      5    125.00  625.00
# 2 2018-09-10  Central     Gill  Pencil      7      1.29    9.03
# 3 2018-11-17  Central  Jardine  Binder     11      4.99   54.89
# 4 2018-10-31  Central  Andrews  Pencil     14      1.29   18.06

# %%
# Combine the data into one using aapend
c= df1.append(df2,ignore_index=True)
c.head()
# Out:
#    OrderDate   Region      Rep    Item  Units  UnitCost   Total
# 0 2018-09-01  Central    Smith    Desk      2    125.00  250.00
# 1 2018-06-17  Central   Kivell    Desk      5    125.00  625.00
# 2 2018-09-10  Central     Gill  Pencil      7      1.29    9.03
# 3 2018-11-17  Central  Jardine  Binder     11      4.99   54.89
# 4 2018-10-31  Central  Andrews  Pencil     14      1.29   18.06

# %% [markdown]
# ### <br><br>Data aggregation
#
# Data aggregation means taking many data points and reducing them to one number, whether it's a count, sum, mean, or other single statistic. Here are some DataFrame method functions:

# %% [markdown]
# - [`.count()`](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.count.html)
# - [`.sum()`](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.sum.html)
# - [`.mean()`](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.mean.html)
# - [`.median()`](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.median.html)
# - [`.min()`](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.min.html)
# - [`.max()`](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.max.html)
# - [`.unique()`](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.Series.unique.html)
# - [`.nunique()`](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.Series.nunique.html)
# - [`.std()`](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.std.html)   #Standard error
# - [`.var()`](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.var.html)   #Variance
# - And more!

# %%
# Using count
combine.count()
# Out:
# OrderDate    86
# Region       86
# Rep          86
# Item         86
# Units        86
# UnitCost     86
# Total        86
# dtype: int64

# %%
# Using sum
combine.sum()
# Out:
# Region      CentralCentralCentralCentralCentralCentralCent...
# Rep         SmithKivellGillJardineAndrewsGillMorganAndrews...
# Item        DeskDeskPencilBinderPencilPenBinderBinderPenci...
# Units                                                    4242
# UnitCost                                              1746.54
# Total                                                 39255.8
# dtype: object

# %%
#Using describe
#Summary statistics
# Display a statistical overview of the DataFrame
combine.describe()
# Out:
#            Units    UnitCost        Total
# count  86.000000   86.000000    86.000000
# mean   49.325581   20.308605   456.462326
# std    29.900794   47.065793   444.384782
# min     2.000000    1.290000     9.030000
# 25%    27.250000    3.490000   142.260000
# 50%    53.000000    4.990000   299.400000
# 75%    74.750000   18.990000   612.590000
# max    96.000000  275.000000  1879.060000

# %%
# we can generate the relationship between each continuous variable:
combine.corr()
# Out:
#              Units  UnitCost     Total
# Units     1.000000 -0.392016  0.408099
# UnitCost -0.392016  1.000000  0.209500
# Total     0.408099  0.209500  1.000000

# %%
#Using sample
# Provides a random sample of your dataframe.
combine.sample(5)
# Out:
#     OrderDate   Region      Rep     Item  Units  UnitCost    Total
# 78 2020-04-27     East   Howard      Pen     96      4.99   479.04
# 33 2017-12-29     East   Parent  Pen Set     74     15.99  1183.26
# 44 2019-02-09  Central  Jardine   Pencil     36      4.99   179.64
# 5  2017-02-26  Central     Gill      Pen     27     19.99   539.73
# 0  2018-09-01  Central    Smith     Desk      2    125.00   250.00

# %%
# .value_counts() can tell us the frequency of all values in a column:
df1['Rep'].value_counts()
# Out:
# Jones       8
# Gill        5
# Jardine     5
# Kivell      4
# Andrews     4
# Sorvino     4
# Parent      3
# Morgan      3
# Smith       3
# Howard      2
# Thompson    2
# Name: Rep, dtype: int64

# %%
# .value_counts() can tell us the frequency of all values in a column:
df1['Item'].value_counts()
# Out:
# Binder     15
# Pencil     13
# Pen Set     7
# Pen         5
# Desk        3
# Name: Item, dtype: int64

# %%
# Selecting specific columns 
combine[['Region', 'Item','Total']].head()
# Out:
#     Region    Item   Total
# 0  Central    Desk  250.00
# 1  Central    Desk  625.00
# 2  Central  Pencil    9.03
# 3  Central  Binder   54.89
# 4  Central  Pencil   18.06

# %%
# Selecting specific columns 
combine[['Region', 'Item','Total','Rep']].head()
# Out:
#     Region    Item   Total      Rep
# 0  Central    Desk  250.00    Smith
# 1  Central    Desk  625.00   Kivell
# 2  Central  Pencil    9.03     Gill
# 3  Central  Binder   54.89  Jardine
# 4  Central  Pencil   18.06  Andrews

# %%
# Selecting specific rows
combine[0:5]
# Out:
#    OrderDate   Region      Rep    Item  Units  UnitCost   Total
# 0 2018-09-01  Central    Smith    Desk      2    125.00  250.00
# 1 2018-06-17  Central   Kivell    Desk      5    125.00  625.00
# 2 2018-09-10  Central     Gill  Pencil      7      1.29    9.03
# 3 2018-11-17  Central  Jardine  Binder     11      4.99   54.89
# 4 2018-10-31  Central  Andrews  Pencil     14      1.29   18.06

# %%
# Selecting specific rows
combine[81:86]
# Out:
#     OrderDate Region       Rep    Item  Units  UnitCost    Total
# 81 2019-05-22   West  Thompson  Pencil     32      1.99    63.68
# 82 2020-03-07   West   Sorvino  Binder      7     19.99   139.93
# 83 2020-08-24   West   Sorvino    Desk      3    275.00   825.00
# 84 2020-09-27   West   Sorvino     Pen     76      1.99   151.24
# 85 2020-10-14   West  Thompson  Binder     57     19.99  1139.43

# %%
#Listing data in columns
l = list(combine['Rep'])
# l

# list print data verically

print(l)

# print function prints data horizontally
# Out:
# ['Smith', 'Kivell', 'Gill', 'Jardine', 'Andrews', 'Gill', 'Morgan', 'Andrews', 'Jardine', 'Kivell', 'Gill', 'Kivell', 'Jardine', 'Gill', 'Morgan', 'Andrews', 'Smith', 'Andrews', 'Gill', 'Smith', 'Jardine', 'Morgan', 'Jardine', 'Kivell', 'Jones', 'Parent', 'Jones', 'Howard', 'Jones', 'Jones', 'Jones', 'Jones', 'Jones', 'Parent', 'Parent', 'Jones', 'Howard', 'Sorvino', 'Sorvino', 'Thompson', 'Sorvino', 'Thompson', 'Sorvino', 'Kivell', 'Jardine', 'Gill', 'Andrews', 'Jardine', 'Morgan', 'Smith', 'Morgan', 'Kivell', 'Smith', 'Gill', 'Smith', 'Jardine', 'Andrews', 'Gill', 'Gill', 'Kivell', 'Morgan', 'Kivell', 'Gill', 'Andrews', 'Jardine', 'Jardine', 'Andrews', 'Jones', 'Jones', 'Jones', 'Howard', 'Parent', 'Jones', 'Jones', 'Jones', 'Parent', 'Parent', 'Jones', 'Howard', 'Jones', 'Sorvino', 'Thompson', 'Sorvino', 'Sorvino', 'Sorvino', 'Thompson']

# %%
#Sorting data 
combine.sort_values(by='Units').head()
# Out:
#     OrderDate   Region      Rep    Item  Units  UnitCost   Total
# 0  2018-09-01  Central    Smith    Desk      2    125.00  250.00
# 49 2019-09-01  Central    Smith    Desk      2    125.00  250.00
# 37 2018-08-24     West  Sorvino    Desk      3    275.00  825.00
# 83 2020-08-24     West  Sorvino    Desk      3    275.00  825.00
# 24 2018-02-18     East    Jones  Binder      4      4.99   19.96

# %%
#Sorting data 
combine.sort_values(by='Rep').head()
# Out:
#     OrderDate   Region      Rep    Item  Units  UnitCost   Total
# 63 2020-10-31  Central  Andrews  Pencil     14      1.29   18.06
# 17 2017-04-18  Central  Andrews  Pencil     75      1.99  149.25
# 66 2020-12-21  Central  Andrews  Binder     28      4.99  139.72
# 4  2018-10-31  Central  Andrews  Pencil     14      1.29   18.06
# 15 2018-04-10  Central  Andrews  Pencil     66      1.99  131.34

# %%
#Add column year and extract data from Date.
Year = ""
combine['Year'] = pd.DatetimeIndex(combine.OrderDate).year
combine
# Out:
#     OrderDate   Region       Rep    Item  Units  UnitCost    Total  Year
# 0  2018-09-01  Central     Smith    Desk      2    125.00   250.00  2018
# 1  2018-06-17  Central    Kivell    Desk      5    125.00   625.00  2018
# 2  2018-09-10  Central      Gill  Pencil      7      1.29     9.03  2018
# 3  2018-11-17  Central   Jardine  Binder     11      4.99    54.89  2018
# 4  2018-10-31  Central   Andrews  Pencil     14      1.29    18.06  2018
# ..        ...      ...       ...     ...    ...       ...      ...   ...
# 81 2019-05-22     West  Thompson  Pencil     32      1.99    63.68  2019
# 82 2020-03-07     West   Sorvino  Binder      7     19.99   139.93  2020
# 83 2020-08-24     West   Sorvino    Desk      3    275.00   825.00  2020
# 84 2020-09-27     West   Sorvino     Pen     76      1.99   151.24  2020
# 85 2020-10-14     West  Thompson  Binder     57     19.99  1139.43  2020
#
# [86 rows x 8 columns]

# %%
# Finding Specific information 
combine[(combine['Year']==2017)].head(10)
# Out:
#     OrderDate   Region      Rep     Item  Units  UnitCost   Total  Year
# 5  2017-02-26  Central     Gill      Pen     27     19.99  539.73  2017
# 6  2017-10-05  Central   Morgan   Binder     28      8.99  251.72  2017
# 8  2017-02-09  Central  Jardine   Pencil     36      4.99  179.64  2017
# 11 2017-01-23  Central   Kivell   Binder     50     19.99  999.50  2017
# 16 2017-12-12  Central    Smith   Pencil     67      1.29   86.43  2017
# 17 2017-04-18  Central  Andrews   Pencil     75      1.99  149.25  2017
# 20 2017-05-05  Central  Jardine   Pencil     90      4.99  449.10  2017
# 21 2017-06-25  Central   Morgan   Pencil     90      4.99  449.10  2017
# 23 2017-11-25  Central   Kivell  Pen Set     96      4.99  479.04  2017
# 25 2017-11-08     East   Parent      Pen     15     19.99  299.85  2017

# %%
# Finding Specific information 
combine[(combine['Rep']=='Jones')].head(10)
# Out:
#     OrderDate Region    Rep     Item  Units  UnitCost   Total  Year
# 24 2018-02-18   East  Jones   Binder      4      4.99   19.96  2018
# 26 2017-09-18   East  Jones  Pen Set     16     15.99  255.84  2017
# 28 2017-08-18   East  Jones   Pencil     35      4.99  174.65  2017
# 29 2017-04-01   East  Jones   Binder     60      4.99  299.40  2017
# 30 2017-06-08   East  Jones   Binder     60      8.99  539.40  2017
# 31 2018-07-04   East  Jones  Pen Set     62      4.99  309.38  2018
# 32 2017-10-22   East  Jones      Pen     64      8.99  575.36  2017
# 35 2017-01-06   East  Jones   Pencil     95      1.99  189.05  2017
# 67 2019-01-06   East  Jones   Pencil     95      1.99  189.05  2019
# 68 2019-04-01   East  Jones   Binder     60      4.99  299.40  2019

# %%
# Finding Specific information using AND
combine[(combine['Rep']=='Jones') & (combine['Units'] < 20 )]
# Out:
#     OrderDate Region    Rep     Item  Units  UnitCost   Total  Year
# 24 2018-02-18   East  Jones   Binder      4      4.99   19.96  2018
# 26 2017-09-18   East  Jones  Pen Set     16     15.99  255.84  2017
# 73 2019-09-18   East  Jones  Pen Set     16     15.99  255.84  2019
# 77 2020-02-18   East  Jones   Binder      4      4.99   19.96  2020

# %%
# Finding Specific information using OR
combine[(combine['Rep']=='Jones') | (combine['Units'] > 10 )].head(10)
# Out:
#     OrderDate   Region      Rep     Item  Units  UnitCost    Total  Year
# 3  2018-11-17  Central  Jardine   Binder     11      4.99    54.89  2018
# 4  2018-10-31  Central  Andrews   Pencil     14      1.29    18.06  2018
# 5  2017-02-26  Central     Gill      Pen     27     19.99   539.73  2017
# 6  2017-10-05  Central   Morgan   Binder     28      8.99   251.72  2017
# 7  2018-12-21  Central  Andrews   Binder     28      4.99   139.72  2018
# 8  2017-02-09  Central  Jardine   Pencil     36      4.99   179.64  2017
# 9  2018-08-07  Central   Kivell  Pen Set     42     23.95  1005.90  2018
# 10 2018-01-18  Central     Gill   Binder     46      8.99   413.54  2018
# 11 2017-01-23  Central   Kivell   Binder     50     19.99   999.50  2017
# 12 2018-03-24  Central  Jardine  Pen Set     50      4.99   249.50  2018

# %% [markdown]
# ## <br><br>Saving your changed DataFrame

# %% [markdown]
# ### Excel vs. CSV(Comma Seperated Values)
#
# ### Excel
# - It is a binary file that holds information about all the worksheets in a workbook
# - Files saved in excel cannot be opened or edited by text editors
# - Excel consumes more memory while importing data
# - As a developer, it's difficult to programmatically manipulate Excel files since the Excel is proprietary.
#
# ### CSV
# - CSV stands for Comma Separated Values. It is a plain text format with a series of values separated by commas
# - CSV files can be opened or edited by text editors like notepad
# - Importing CSV files can be much faster, and it also consumes less memory
# - As a developer it's easy to programmatically manipulate CSV since, after all, they are simple text files.

# %%
# Save as a excel file

save = df1.to_excel('new.xlsx')

# Save as a CSV file

save1 = df1.to_excel('new.csv')

# %% [markdown]
# ## Basic Plots

# %%
scatter = combine.plot(kind="scatter", x="Region", y="Total")

# %%
bar = combine.groupby("Item")["Units"].mean().plot(kind = 'bar', 
                                                              title = "Size by Item")

# %% [markdown]
# ## Homework, explore another python dependency.

# %%
# Explore python Statistics this is primarily used for descriptive statistics. 

# !pip install statistics

# https://docs.python.org/3/library/statistics.html 
# https://realpython.com/python-statistics/ 

# mean(): Arithmetic mean (“average”) of data.

# harmonic_mean(): Harmonic mean of data.

# median(): Median (middle value) of data.

# median_low(): Low median of data.

# median_high(): High median of data.

# median_grouped(): Median, or 50th percentile, of grouped data.

# mode(): Single mode (most common value) of discrete or nominal data.

# pstdev(): Population standard deviation of data.

# pvariance(): Population variance of data.

# stdev(): Sample standard deviation of data.

# variance(): Sample variance of data.
# Out:
# Requirement already satisfied: statistics in c:\users\jgj2079\documents\new folder\lib\site-packages (1.0.3.5)
# Requirement already satisfied: docutils>=0.3 in c:\users\jgj2079\documents\new folder\lib\site-packages (from statistics) (0.16)

# %%
import statistics
